# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_excel("/content/Exercise 15 Regression Trees Strength2.xlsx")

# Define features and target
X = df.drop(columns=["Strength2"])
y = df["Strength2"]

# %%
# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the LightGBM Regressor
lgbm = LGBMRegressor(n_estimators=100, random_state=42)

# Fit the model on training data
lgbm.fit(X_train, y_train)

# Predict on both train and validation sets
y_train_pred = lgbm.predict(X_train)
y_val_pred = lgbm.predict(X_val)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009563 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51612
# [LightGBM] [Info] Number of data points in the train set: 3087, number of used features: 219
# [LightGBM] [Info] Start training from score 1820.477087

# %%
# Evaluate Model Performance

## R² score
r2_train = r2_score(y_train, y_train_pred)
r2_val = r2_score(y_val, y_val_pred)

## RMSE (Root Mean Squared Error)
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred))

## Display performance metrics
print("Training R²:", round(r2_train, 4))
print("Training RMSE:", round(rmse_train, 4))
print("Validation R²:", round(r2_val, 4))
print("Validation RMSE:", round(rmse_val, 4))
# Out:
# Training R²: 0.9727
# Training RMSE: 57.4478
# Validation R²: 0.8397
# Validation RMSE: 137.6501
